# %%
import glob
from esbl_vis import *

# %%
files = glob.glob("./data/set_1/*")  # Change path or list files that need to be processed
all_raw, all_meta = read_data(files)
# Out:
# Starting data import...
# File list:
# ./data/set_1/Amoxicillin-clavulanate_150ug_1-2_Azithromycin_160ug_1-2_21-kesä-2023 15-04-00.xlsx
# ./data/set_1/H2O2_5mM_1-2_DFOA_100ug_1-2_22-kesä-2023 15-26-31.xlsx
# ./data/set_1/Amoxicillin-clavulanate_300ug_1-2_Azithromycin_320ug_1-2_22-kesä-2023 15-25-01.xlsx
# ./data/set_1/Trimethroprim_320ug_1-2_Control_1-2__21-kesä-2023 15-03-42.xlsx
#
# Processing: ./data/set_1/Amoxicillin-clavulanate_150ug_1-2_Azithromycin_160ug_1-2_21-kesä-2023 15-04-00.xlsx
# Plate 1
# Replaced imported date 1900-01-01 00:00:02 with 24:00:02
# Using ./data/set_1/Amoxicillin-clavulanate_150ug_1-2_Azithromycin_160ug_1-2_21-kesä-2023 15-04-00.xlsx time values as reference
# Using ./data/set_1/Amoxicillin-clavulanate_150ug_1-2_Azithromycin_160ug_1-2_21-kesä-2023 15-04-00.xlsx metadata columns as reference
# Using ./data/set_1/Amoxicillin-clavulanate_150ug_1-2_Azithromycin_160ug_1-2_21-kesä-2023 15-04-00.xlsx raw data well names as reference
# Plate 2
# ...

# %%
plot_od_rho_heatmaps(all_raw, all_meta)

# %%
plot_end_ods(all_raw, all_meta, figsize=(17, 8*5))
